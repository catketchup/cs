# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = 'output/'
n = 10
type = 'sin'
title = '$sin_{n}$'

# %%
x = np.arange(0,10,1)
y = np.sin(x)

data_dict = {'x':x,'y':y}
data_df = pd.DataFrame(data_dict)
data_df.to_csv(path+f'ell={ell}.csv',index=False)

# %%
plt.plot(x,y)
plt.title(title)
plt.show()
